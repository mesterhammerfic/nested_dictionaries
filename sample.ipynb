# %%
jason=student


data = {
    "Aaron Johnson": {
        "sub_percent": 70.76923076923077,
        "win_percent": 54.621848739495796,
        "match_count": 119,
        "win_count": 65,
        "leg_lock_count": 28,
        "sub_variety": 19,
        "sub_count": 46,
        "leg_lock_percent": 60.86956521739131,
        "years_active": [
            "2015",
            "2016",
            "2017",
            "2018",
            "2019",
            "2020"
        ],
        "years_active_count": 6,
        "weight_classes": [
            "ABS",
            "92KG",
            "HWABS",
            "97KG",
            "99KG",
            "84KG",
            "93KG",
            "U110KG",
            "94KG",
            "95KG",
            "85KG",
            "N/A",
            "100KG",
            "110KG"
        ],
        "by_year": {
            "2015": {
                "sub_percent": 100.0,
                "win_percent": 40.0,
                "match_count": 5,
                "win_count": 2,
                "leg_lock_count": 2,
                "sub_variety": 2,
                "sub_count": 2,
                "leg_lock_percent": 100.0,
                "years_active": [
                    "2015"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "ABS",
                    "94KG"
                ]
            },
            "2016": {
                "sub_percent": 62.5,
                "win_percent": 42.10526315789473,
                "match_count": 19,
                "win_count": 8,
                "leg_lock_count": 3,
                "sub_variety": 4,
                "sub_count": 5,
                "leg_lock_percent": 60.0,
                "years_active": [
                    "2016"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "ABS",
                    "HWABS",
                    "97KG",
                    "84KG",
                    "94KG",
                    "100KG"
                ]
            },
            "2017": {
                "sub_percent": 46.666666666666664,
                "win_percent": 51.724137931034484,
                "match_count": 29,
                "win_count": 15,
                "leg_lock_count": 3,
                "sub_variety": 5,
                "sub_count": 7,
                "leg_lock_percent": 42.857142857142854,
                "years_active": [
                    "2017"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "ABS",
                    "97KG",
                    "U110KG",
                    "94KG",
                    "N/A",
                    "100KG",
                    "110KG"
                ]
            },
            "2018": {
                "sub_percent": 66.66666666666666,
                "win_percent": 65.625,
                "match_count": 32,
                "win_count": 21,
                "leg_lock_count": 10,
                "sub_variety": 8,
                "sub_count": 14,
                "leg_lock_percent": 71.42857142857143,
                "years_active": [
                    "2018"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "ABS",
                    "97KG",
                    "93KG",
                    "99KG",
                    "94KG",
                    "95KG",
                    "85KG",
                    "100KG",
                    "110KG"
                ]
            },
            "2019": {
                "sub_percent": 94.44444444444444,
                "win_percent": 56.25,
                "match_count": 32,
                "win_count": 18,
                "leg_lock_count": 9,
                "sub_variety": 11,
                "sub_count": 17,
                "leg_lock_percent": 52.94117647058824,
                "years_active": [
                    "2019"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "ABS",
                    "92KG",
                    "97KG",
                    "93KG",
                    "99KG",
                    "94KG",
                    "100KG"
                ]
            },
            "2020": {
                "sub_percent": 100.0,
                "win_percent": 50.0,
                "match_count": 2,
                "win_count": 1,
                "leg_lock_count": 1,
                "sub_variety": 1,
                "sub_count": 1,
                "leg_lock_percent": 100.0,
                "years_active": [
                    "2020"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "ABS",
                    "N/A"
                ]
            }
        },
        "by_weight": {
            "ABS": {
                "sub_percent": 74.07407407407408,
                "win_percent": 55.10204081632652,
                "match_count": 49,
                "win_count": 27,
                "leg_lock_count": 12,
                "sub_variety": 10,
                "sub_count": 20,
                "leg_lock_percent": 60.0,
                "years_active": [
                    "2015",
                    "2016",
                    "2017",
                    "2018",
                    "2019",
                    "2020"
                ],
                "years_active_count": 6,
                "weight_classes": [
                    "ABS"
                ]
            },
            "92KG": {
                "sub_percent": 0,
                "win_percent": 0.0,
                "match_count": 1,
                "win_count": 0,
                "leg_lock_count": 0,
                "sub_variety": 0,
                "sub_count": 0,
                "leg_lock_percent": 0,
                "years_active": [
                    "2019"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "92KG"
                ]
            },
            "HWABS": {
                "sub_percent": 0,
                "win_percent": 0.0,
                "match_count": 1,
                "win_count": 0,
                "leg_lock_count": 0,
                "sub_variety": 0,
                "sub_count": 0,
                "leg_lock_percent": 0,
                "years_active": [
                    "2016"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "HWABS"
                ]
            },
            "97KG": {
                "sub_percent": 70.0,
                "win_percent": 58.82352941176471,
                "match_count": 17,
                "win_count": 10,
                "leg_lock_count": 4,
                "sub_variety": 6,
                "sub_count": 7,
                "leg_lock_percent": 57.14285714285714,
                "years_active": [
                    "2016",
                    "2017",
                    "2018",
                    "2019"
                ],
                "years_active_count": 4,
                "weight_classes": [
                    "97KG"
                ]
            },
            "99KG": {
                "sub_percent": 100.0,
                "win_percent": 80.0,
                "match_count": 5,
                "win_count": 4,
                "leg_lock_count": 2,
                "sub_variety": 3,
                "sub_count": 4,
                "leg_lock_percent": 50.0,
                "years_active": [
                    "2018",
                    "2019"
                ],
                "years_active_count": 2,
                "weight_classes": [
                    "99KG"
                ]
            },
            "84KG": {
                "sub_percent": 0,
                "win_percent": 0.0,
                "match_count": 1,
                "win_count": 0,
                "leg_lock_count": 0,
                "sub_variety": 0,
                "sub_count": 0,
                "leg_lock_percent": 0,
                "years_active": [
                    "2016"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "84KG"
                ]
            },
            "93KG": {
                "sub_percent": 100.0,
                "win_percent": 40.0,
                "match_count": 5,
                "win_count": 2,
                "leg_lock_count": 2,
                "sub_variety": 1,
                "sub_count": 2,
                "leg_lock_percent": 100.0,
                "years_active": [
                    "2018",
                    "2019"
                ],
                "years_active_count": 2,
                "weight_classes": [
                    "93KG"
                ]
            },
            "U110KG": {
                "sub_percent": 100.0,
                "win_percent": 33.33333333333333,
                "match_count": 3,
                "win_count": 1,
                "leg_lock_count": 0,
                "sub_variety": 1,
                "sub_count": 1,
                "leg_lock_percent": 0.0,
                "years_active": [
                    "2017"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "U110KG"
                ]
            },
            "94KG": {
                "sub_percent": 70.0,
                "win_percent": 58.82352941176471,
                "match_count": 17,
                "win_count": 10,
                "leg_lock_count": 6,
                "sub_variety": 4,
                "sub_count": 7,
                "leg_lock_percent": 85.71428571428571,
                "years_active": [
                    "2015",
                    "2016",
                    "2017",
                    "2018",
                    "2019"
                ],
                "years_active_count": 5,
                "weight_classes": [
                    "94KG"
                ]
            },
            "95KG": {
                "sub_percent": 0,
                "win_percent": 0.0,
                "match_count": 1,
                "win_count": 0,
                "leg_lock_count": 0,
                "sub_variety": 0,
                "sub_count": 0,
                "leg_lock_percent": 0,
                "years_active": [
                    "2018"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "95KG"
                ]
            },
            "85KG": {
                "sub_percent": 0.0,
                "win_percent": 50.0,
                "match_count": 2,
                "win_count": 1,
                "leg_lock_count": 0,
                "sub_variety": 0,
                "sub_count": 0,
                "leg_lock_percent": 0,
                "years_active": [
                    "2018"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "85KG"
                ]
            },
            "N/A": {
                "sub_percent": 0.0,
                "win_percent": 50.0,
                "match_count": 2,
                "win_count": 1,
                "leg_lock_count": 0,
                "sub_variety": 0,
                "sub_count": 0,
                "leg_lock_percent": 0,
                "years_active": [
                    "2017",
                    "2020"
                ],
                "years_active_count": 2,
                "weight_classes": [
                    "N/A"
                ]
            },
            "100KG": {
                "sub_percent": 50.0,
                "win_percent": 66.66666666666666,
                "match_count": 9,
                "win_count": 6,
                "leg_lock_count": 1,
                "sub_variety": 3,
                "sub_count": 3,
                "leg_lock_percent": 33.33333333333333,
                "years_active": [
                    "2016",
                    "2017",
                    "2018",
                    "2019"
                ],
                "years_active_count": 4,
                "weight_classes": [
                    "100KG"
                ]
            },
            "110KG": {
                "sub_percent": 66.66666666666666,
                "win_percent": 50.0,
                "match_count": 6,
                "win_count": 3,
                "leg_lock_count": 1,
                "sub_variety": 2,
                "sub_count": 2,
                "leg_lock_percent": 50.0,
                "years_active": [
                    "2017",
                    "2018"
                ],
                "years_active_count": 2,
                "weight_classes": [
                    "110KG"
                ]
            }
        }
    },
    "Abdurakhman Bilarov": {
        "sub_percent": 63.63636363636363,
        "win_percent": 68.75,
        "match_count": 32,
        "win_count": 22,
        "leg_lock_count": 5,
        "sub_variety": 7,
        "sub_count": 14,
        "leg_lock_percent": 35.714285714285715,
        "years_active": [
            "2015",
            "2016",
            "2017",
            "2018",
            "2019"
        ],
        "years_active_count": 5,
        "weight_classes": [
            "ABS",
            "92KG",
            "99KG",
            "94KG",
            "95KG",
            "100KG"
        ],
        "by_year": {
            "2015": {
                "sub_percent": 50.0,
                "win_percent": 100.0,
                "match_count": 2,
                "win_count": 2,
                "leg_lock_count": 1,
                "sub_variety": 1,
                "sub_count": 1,
                "leg_lock_percent": 100.0,
                "years_active": [
                    "2015"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "ABS"
                ]
            },
            "2016": {
                "sub_percent": 50.0,
                "win_percent": 66.66666666666666,
                "match_count": 3,
                "win_count": 2,
                "leg_lock_count": 0,
                "sub_variety": 1,
                "sub_count": 1,
                "leg_lock_percent": 0.0,
                "years_active": [
                    "2016"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "ABS",
                    "94KG"
                ]
            },
            "2017": {
                "sub_percent": 54.54545454545454,
                "win_percent": 68.75,
                "match_count": 16,
                "win_count": 11,
                "leg_lock_count": 4,
                "sub_variety": 3,
                "sub_count": 6,
                "leg_lock_percent": 66.66666666666666,
                "years_active": [
                    "2017"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "94KG",
                    "92KG",
                    "95KG",
                    "99KG"
                ]
            },
            "2018": {
                "sub_percent": 100.0,
                "win_percent": 60.0,
                "match_count": 5,
                "win_count": 3,
                "leg_lock_count": 0,
                "sub_variety": 3,
                "sub_count": 3,
                "leg_lock_percent": 0.0,
                "years_active": [
                    "2018"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "100KG",
                    "95KG"
                ]
            },
            "2019": {
                "sub_percent": 75.0,
                "win_percent": 66.66666666666666,
                "match_count": 6,
                "win_count": 4,
                "leg_lock_count": 0,
                "sub_variety": 2,
                "sub_count": 3,
                "leg_lock_percent": 0.0,
                "years_active": [
                    "2019"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "94KG",
                    "100KG",
                    "95KG"
                ]
            }
        },
        "by_weight": {
            "ABS": {
                "sub_percent": 50.0,
                "win_percent": 66.66666666666666,
                "match_count": 3,
                "win_count": 2,
                "leg_lock_count": 1,
                "sub_variety": 1,
                "sub_count": 1,
                "leg_lock_percent": 100.0,
                "years_active": [
                    "2015",
                    "2016"
                ],
                "years_active_count": 2,
                "weight_classes": [
                    "ABS"
                ]
            },
            "92KG": {
                "sub_percent": 100.0,
                "win_percent": 100.0,
                "match_count": 1,
                "win_count": 1,
                "leg_lock_count": 0,
                "sub_variety": 1,
                "sub_count": 1,
                "leg_lock_percent": 0.0,
                "years_active": [
                    "2017"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "92KG"
                ]
            },
            "99KG": {
                "sub_percent": 0.0,
                "win_percent": 50.0,
                "match_count": 2,
                "win_count": 1,
                "leg_lock_count": 0,
                "sub_variety": 0,
                "sub_count": 0,
                "leg_lock_percent": 0,
                "years_active": [
                    "2017"
                ],
                "years_active_count": 1,
                "weight_classes": [
                    "99KG"
                ]
            },
            "94KG": {
                "sub_percent": 16.666666666666664,
                "win_percent": 66.66666666666666,
                "match_count": 9,
                "win_count": 6,
                "leg_lock_count": 0,
                "sub_variety": 1,
                "sub_count": 1,
                "leg_lock_percent": 0.0,
                "years_active": [
                    "2016",
                    "2017",
                    "2019"
                ],
                "years_active_count": 3,
                "weight_classes": [
                    "94KG"
                ]
            },
            "95KG": {
                "sub_percent": 83.33333333333334,
                "win_percent": 54.54545454545454,
                "match_count": 11,
                "win_count": 6,
                "leg_lock_count": 4,
                "sub_variety": 2,
                "sub_count": 5,
                "leg_lock_percent": 80.0,
                "years_active": [
                    "2017",
                    "2018",
                    "2019"
                ],
                "years_active_count": 3,
                "weight_classes": [
                    "95KG"
                ]
            },
            "100KG": {
                "sub_percent": 100.0,
                "win_percent": 100.0,
                "match_count": 6,
                "win_count": 6,
                "leg_lock_count": 0,
                "sub_variety": 5,
                "sub_count": 6,
                "leg_lock_percent": 0.0,
                "years_active": [
                    "2018",
                    "2019"
                ],
                "years_active_count": 2,
                "weight_classes": [
                    "100KG"
                ]
            }
        }
    }
}
