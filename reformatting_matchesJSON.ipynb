# %%
import json
import pandas as pd

# %% [markdown]
# I used a series of nested dictionaries to store my bjj_matches.JSON, but this has been a convoluted way to organize that data and I want it to fit into a DataFrame without having to access a set of nested dictionaries.

# %%
df = pd.read_json('bjjheroes_matches.json')
df.head(5)
# Out:
#                                              matches                 name
# 0  [{'method': 'Inside heel hook', 'outcome': 'L'...        Aaron Johnson
# 1  [{'method': 'Referee Decision', 'outcome': 'L'...  Abdurakhman Bilarov
# 2  [{'method': 'Adv', 'outcome': 'L', 'weight': '...        Abraham Marte
# 3  [{'method': 'Referee Decision', 'outcome': 'L'...        Adam Benayoun
# 4  [{'method': 'RNC', 'outcome': 'L', 'weight': '...         Adam Ferrara

# %% [markdown]
# I'm going to make it a little neater by opening the matches list for each fighter and adding their name onto each individual match dictionary. First I'm going to open the JSON file and set it as data.

# %%
with open('bjjheroes_matches.json', 'r') as file:
    data = json.load(file)

# %% [markdown]
# Now I'm going to take the first element as a test and figure out how to add their name to each of their matches.

# %%
data[0]
# Out:
# {'matches': [{'method': 'Inside heel hook',
#    'outcome': 'L',
#    'weight': 'ABS',
#    'year': '2015'},
#   {'method': 'RNC', 'outcome': 'L', 'weight': '94KG', 'year': '2015'},
#   {'method': 'Heel hook', 'outcome': 'L', 'weight': 'ABS', 'year': '2015'},
#   {'method': 'Points', 'outcome': 'L', 'weight': '94KG', 'year': '2016'},
#   {'method': 'N/A', 'outcome': 'L', 'weight': '94KG', 'year': '2016'},
#   {'method': 'Cross choke', 'outcome': 'L', 'weight': 'HWABS', 'year': '2016'},
#   {'method': 'Choke', 'outcome': 'L', 'weight': 'ABS', 'year': '2016'},
#   {'method': 'Triangle', 'outcome': 'L', 'weight': '100KG', 'year': '2016'},
#   {'method': 'Triangle armbar',
#    'outcome': 'L',
#    'weight': 'ABS',
#    'year': '2016'},
#   {'method': 'Choke from back',
#    'outcome': 'L',
#    'weight': 'ABS',
#    'year': '2016'},
#   {'method': 'Points', 'outcome': 'L', 'weight': 'ABS', 'year': '2016'},
#   {'method': 'Inside heel hook',
#    'outcome': 'L',
#    'weight': '84KG',
#    'year': '2016'},
#   {'method': 'Arm in guillotine',
#    'outcome': 'L',
#    'weight': 'ABS',
#    'year': '2016'},
#   {'method': 'Pts: 19x0', 'outcome': 'L', 'weight': 'O97KG', 'year': '2016'},
#   {'method': 'Points', 'outcome': 'L', 'weight': '110KG', 'year': '2017'},
#   {'method': 'Pts: 10x0', 'outcome': 'L', 'weight': 'ABS', 'year': '2017'},
#   {'method': 'Points', 'outcome': 'L', 'weight': 'U110KG', 'year': '2017'},
#   {'method': 'Points', 'outcome': 'L', 'weight': 'U110KG', 'year': '2017'},
#   {'method': 'Pts: 4x2', 'outcome': 'L', 'weight': '94KG', 'year': '2017'},
#   {'method': 'Points', 'outcome': 'L', 'weight': 'ABS', 'year': '2017'},
#   {'method': 'Botinha', 'outcome': 'L', 'weight': 'ABS', 'year': '2017'},
#   {'method': 'Brabo choke', 'outcome': 'L', 'weight': '94KG', 'year': '2017'},
#   {'method': 'Calf slicer', 'outcome': 'L', 'weight': 'O97KG', 'year': '2017'},
#   {'method': 'Points', 'outcome': 'L', 'weight': 'ABS', 'year': '2017'},
#   {'method': 'Reverse triangle',
#    'outcome': 'L',
#    'weight': 'ABS',
#    'year': '2017'},
#   {'method': 'Inside heel hook',
#    'outcome': 'L',
#    'weight': 'ABS',
#    'year': '2017'},
#   {'method': 'Pts: 2x0', 'outcome': 'L', 'weight': '97KG', 'year': '2017'},
#   {'method': 'RNC', 'outcome': 'L', 'weight': 'ABS', 'year': '2017'},
#   {'method': 'Pts: 0x0, Adv',
#    'outcome': 'L',
#    'weight': '110KG',
#    'year': '2018'},
#   {'method': 'Points', 'outcome': 'L', 'weight': '110KG', 'year': '2018'},
#   {'method': 'DQ', 'outcome': 'L', 'weight': 'O85KG', 'year': '2018'},
#   {'method': 'Pts: 7x2', 'outcome': 'L', 'weight': '94KG', 'year': '2018'},
#   {'method': 'Triangle armbar',
#    'outcome': 'L',
#    'weight': '93KG',
#    'year': '2018'},
#   {'method': 'Pts: 4x2', 'outcome': 'L', 'weight': '95KG', 'year': '2018'},
#   {'method': 'Referee Decision',
#    'outcome': 'L',
#    'weight': 'ABS',
#    'year': '2018'},
#   {'method': 'DQ', 'outcome': 'L', 'weight': '97KG', 'year': '2018'},
#   {'method': 'DQ', 'outcome': 'L', 'weight': 'ABS', 'year': '2018'},
#   {'method': 'Pts: 6x0', 'outcome': 'L', 'weight': 'O97KG', 'year': '2018'},
#   {'method': 'Pts: 5x0', 'outcome': 'L', 'weight': 'ABS', 'year': '2018'},
#   {'method': 'Pts: 34x0', 'outcome': 'L', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'Pts: 15x0', 'outcome': 'L', 'weight': '94KG', 'year': '2019'},
#   {'method': 'Pts: 6x1', 'outcome': 'L', 'weight': '93KG', 'year': '2019'},
#   {'method': 'Choke', 'outcome': 'L', 'weight': '100KG', 'year': '2019'},
#   {'method': 'RNC', 'outcome': 'L', 'weight': '92KG', 'year': '2019'},
#   {'method': 'Referee Decision',
#    'outcome': 'L',
#    'weight': '100KG',
#    'year': '2019'},
#   {'method': 'Pts: 11x0', 'outcome': 'L', 'weight': 'O97KG', 'year': '2019'},
#   {'method': 'Pts: 3x0', 'outcome': 'L', 'weight': '99KG', 'year': '2019'},
#   {'method': 'Pts: 3x0', 'outcome': 'L', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'EBI/OT', 'outcome': 'L', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'EBI/OT', 'outcome': 'L', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'Triangle armbar',
#    'outcome': 'L',
#    'weight': 'ABS',
#    'year': '2019'},
#   {'method': 'Referee Decision',
#    'outcome': 'L',
#    'weight': '97KG',
#    'year': '2019'},
#   {'method': 'Katagatame', 'outcome': 'L', 'weight': 'N/A', 'year': '2020'},
#   {'method': 'Toe hold', 'outcome': 'W', 'weight': '94KG', 'year': '2015'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': '94KG',
#    'year': '2015'},
#   {'method': 'Points', 'outcome': 'W', 'weight': 'ABS', 'year': '2016'},
#   {'method': 'Points', 'outcome': 'W', 'weight': 'ABS', 'year': '2016'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': '94KG',
#    'year': '2016'},
#   {'method': 'Choke from back',
#    'outcome': 'W',
#    'weight': '100KG',
#    'year': '2016'},
#   {'method': 'Pts: 0x0, Adv', 'outcome': 'W', 'weight': 'ABS', 'year': '2016'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'O97KG',
#    'year': '2016'},
#   {'method': 'Flying armbar', 'outcome': 'W', 'weight': 'ABS', 'year': '2016'},
#   {'method': 'Toe hold', 'outcome': 'W', 'weight': 'O97KG', 'year': '2016'},
#   {'method': 'Toe hold', 'outcome': 'W', 'weight': '110KG', 'year': '2017'},
#   {'method': 'Submission', 'outcome': 'W', 'weight': 'U110KG', 'year': '2017'},
#   {'method': 'Points', 'outcome': 'W', 'weight': 'O100KG', 'year': '2017'},
#   {'method': 'Points', 'outcome': 'W', 'weight': 'O100KG', 'year': '2017'},
#   {'method': 'Points', 'outcome': 'W', 'weight': 'ABS', 'year': '2017'},
#   {'method': 'Pts: 7x6', 'outcome': 'W', 'weight': '94KG', 'year': '2017'},
#   {'method': 'Referee Decision',
#    'outcome': 'W',
#    'weight': '94KG',
#    'year': '2017'},
#   {'method': 'Referee Decision',
#    'outcome': 'W',
#    'weight': 'N/A',
#    'year': '2017'},
#   {'method': 'Armbar', 'outcome': 'W', 'weight': '97KG', 'year': '2017'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2017'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'O97KG',
#    'year': '2017'},
#   {'method': 'Referee Decision',
#    'outcome': 'W',
#    'weight': 'O97KG',
#    'year': '2017'},
#   {'method': 'EBI/OT', 'outcome': 'W', 'weight': 'ABS', 'year': '2017'},
#   {'method': 'Armbar', 'outcome': 'W', 'weight': 'ABS', 'year': '2017'},
#   {'method': 'Pts: 4x0', 'outcome': 'W', 'weight': '97KG', 'year': '2017'},
#   {'method': 'Choke from back',
#    'outcome': 'W',
#    'weight': '110KG',
#    'year': '2018'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': '94KG',
#    'year': '2018'},
#   {'method': 'Kneebar', 'outcome': 'W', 'weight': '94KG', 'year': '2018'},
#   {'method': 'Pts: 4x2', 'outcome': 'W', 'weight': '110KG', 'year': '2018'},
#   {'method': 'Adv', 'outcome': 'W', 'weight': 'O85KG', 'year': '2018'},
#   {'method': 'Calf slicer', 'outcome': 'W', 'weight': 'ABS', 'year': '2018'},
#   {'method': 'Kneebar', 'outcome': 'W', 'weight': 'ABS', 'year': '2018'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': '94KG',
#    'year': '2018'},
#   {'method': 'Points', 'outcome': 'W', 'weight': '100KG', 'year': '2018'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': '100KG',
#    'year': '2018'},
#   {'method': 'Pts: 2x0', 'outcome': 'W', 'weight': '97KG', 'year': '2018'},
#   {'method': 'Footlock', 'outcome': 'W', 'weight': '97KG', 'year': '2018'},
#   {'method': 'Referee Decision',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2018'},
#   {'method': 'Reverse triangle',
#    'outcome': 'W',
#    'weight': 'O99KG',
#    'year': '2018'},
#   {'method': 'Triangle armbar',
#    'outcome': 'W',
#    'weight': 'O99KG',
#    'year': '2018'},
#   {'method': 'Kneebar', 'outcome': 'W', 'weight': 'O99KG', 'year': '2018'},
#   {'method': 'Kneebar', 'outcome': 'W', 'weight': 'O99KG', 'year': '2018'},
#   {'method': 'Points', 'outcome': 'W', 'weight': 'ABS', 'year': '2018'},
#   {'method': 'Triangle', 'outcome': 'W', 'weight': 'O97KG', 'year': '2018'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2018'},
#   {'method': 'Pts: 10x2', 'outcome': 'W', 'weight': 'ABS', 'year': '2018'},
#   {'method': 'Pts: 1x0', 'outcome': 'W', 'weight': '94KG', 'year': '2019'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2019'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2019'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2019'},
#   {'method': 'Choke from back',
#    'outcome': 'W',
#    'weight': '94KG',
#    'year': '2019'},
#   {'method': 'Inside heel hook',
#    'outcome': 'W',
#    'weight': '93KG',
#    'year': '2019'},
#   {'method': '---', 'outcome': 'D', 'weight': '93KG', 'year': '2019'},
#   {'method': 'Inside heel hook',
#    'outcome': 'W',
#    'weight': '93KG',
#    'year': '2019'},
#   {'method': 'Mounted choke',
#    'outcome': 'W',
#    'weight': '100KG',
#    'year': '2019'},
#   {'method': 'Submission', 'outcome': 'W', 'weight': 'O97KG', 'year': '2019'},
#   {'method': 'Armlock', 'outcome': 'W', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'Kimura', 'outcome': 'W', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2019'},
#   {'method': 'Heel hook', 'outcome': 'W', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'Heel hook', 'outcome': 'W', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'Kneebar', 'outcome': 'W', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'EBI/OT', 'outcome': 'W', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'Straignt ankle lock',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2019'},
#   {'method': 'EBI/OT', 'outcome': 'W', 'weight': 'ABS', 'year': '2019'},
#   {'method': 'Straight ankle lock',
#    'outcome': 'W',
#    'weight': 'ABS',
#    'year': '2020'}],
#  'name': 'Aaron Johnson'}

# %% [markdown]
# Maybe I can iterate through each element of the matches list and add the name attached to the key 'name'. I'll go ahead and set this to a new variable instead of overwriting the old one. We'll call it test_matches

# %%
test_matches = []
for item in data[0]['matches']:
    new_item = item
    new_item['name'] = data[0]['name']
    test_matches.append(item)
test_matches[:2]
# Out:
# [{'method': 'Inside heel hook',
#   'outcome': 'L',
#   'weight': 'ABS',
#   'year': '2015',
#   'name': 'Aaron Johnson'},
#  {'method': 'RNC',
#   'outcome': 'L',
#   'weight': '94KG',
#   'year': '2015',
#   'name': 'Aaron Johnson'}]

# %% [markdown]
# Cool, now lets see if we can do that for all of them. I'll rewrite the above code as a function.

# %%
def fix_matches_list(fighter_dict):
    new_matches = []
    for item in fighter_dict['matches']:
        new_item = item
        new_item['name'] = fighter_dict['name']
        new_matches.append(item)
    return new_matches

fix_matches_list(data[0]) == test_matches
# Out:
# True

# %% [markdown]
# Now that we have that working we can apply it to every fighter in the list.

# %%
new_data = [fix_matches_list(fighter_dict) for fighter_dict in data]
print(new_data[0][:3])
print(new_data[-1][:3])
# Out:
# [{'method': 'Inside heel hook', 'outcome': 'L', 'weight': 'ABS', 'year': '2015', 'name': 'Aaron Johnson'}, {'method': 'RNC', 'outcome': 'L', 'weight': '94KG', 'year': '2015', 'name': 'Aaron Johnson'}, {'method': 'Heel hook', 'outcome': 'L', 'weight': 'ABS', 'year': '2015', 'name': 'Aaron Johnson'}]
# [{'method': 'N/A', 'outcome': 'L', 'weight': '82KG', 'year': '2016', 'name': 'Vinicius Garcia'}, {'method': 'Armbar', 'outcome': 'L', 'weight': '82KG', 'year': '2016', 'name': 'Vinicius Garcia'}, {'method': 'Points', 'outcome': 'L', 'weight': '82KG', 'year': '2016', 'name': 'Vinicius Garcia'}]

# %% [markdown]
# The only downside to this is that they are not all in the same list, but rather they are each in their own list. Just out of curiosity, I'll see what happens when I try setting this as a dataframe

# %%
test_df = pd.DataFrame(new_data)
test_df.head()
# Out:
#                                                  0    \
# 0  {'method': 'Inside heel hook', 'outcome': 'L',...
# 1  {'method': 'Referee Decision', 'outcome': 'L',...
# 2  {'method': 'Adv', 'outcome': 'L', 'weight': 'O...
# 3  {'method': 'Referee Decision', 'outcome': 'L',...
# 4  {'method': 'RNC', 'outcome': 'L', 'weight': '6...
#
#                                                  1    \
# 0  {'method': 'RNC', 'outcome': 'L', 'weight': '9...
# 1  {'method': 'Pts: 8x2', 'outcome': 'L', 'weight...
# 2  {'method': 'Kneebar', 'outcome': 'L', 'weight'...
# 3  {'method': 'Points', 'outcome': 'L', 'weight':...
# 4  {'method': 'Pts: 4x2', 'outcome': 'L', 'weight...
#
#                                                  2    \
# 0  {'method': 'Heel hook', 'outcome': 'L', 'weigh...
# 1  {'method': 'Referee Decision', 'outcome': 'L',...
# 2  {'method': 'DQ', 'outcome': 'L', 'weight': 'O1...
# 3  {'method': 'Pts: 2x2, Adv', 'outcome': 'L', 'w...
# 4  {'method': 'Choke from back', 'outcome': 'L', ...
#
#                                                  3    \
# 0  {'method': 'Points', 'outcome': 'L', 'weight':...
# 1  {'method': 'DQ', 'outcome': 'L', 'weight': '94...
# 2  {'method': 'Estima lock', 'outcome': 'L', 'wei...
# 3  {'method': 'Pts: 8x6', 'outcome': 'L', 'weight...
# 4  {'method': 'Adv', 'outcome': 'L', 'weight': '6...
#
#                                                  4    \
# 0  {'method': 'N/A', 'outcome': 'L', 'weight': '9...
# 1  {'method': 'Pts: 5x0', 'outcome': 'L', 'weight...
# 2  {'method': 'Choke from back', 'outcome': 'L', ...
# 3  {'method': 'Arm in Ezekiel', 'outcome': 'L', '...
# 4  {'method': 'Pts: 2x2, Adv', 'outcome': 'L', 'w...
#
#                                                  5    \
# 0  {'method': 'Cross choke', 'outcome': 'L', 'wei...
# 1  {'method': 'Arm in guillotine', 'outcome': 'L'...
# 2  {'method': 'Armbar', 'outcome': 'L', 'weight':...
# 3  {'method': 'Points', 'outcome': 'L', 'weight':...
# 4  {'method': 'Referee Decision', 'outcome': 'L',...
#
#                                                  6    \
# 0  {'method': 'Choke', 'outcome': 'L', 'weight': ...
# 1  {'method': 'Referee Decision', 'outcome': 'L',...
# 2  {'method': 'wristlock', 'outcome': 'L', 'weigh...
# 3  {'method': 'Kneebar', 'outcome': 'L', 'weight'...
# 4  {'method': 'Pts: 0x0, Adv', 'outcome': 'L', 'w...
#
#                                                  7    \
# 0  {'method': 'Triangle', 'outcome': 'L', 'weight...
# 1  {'method': 'Points', 'outcome': 'L', 'weight':...
# 2  {'method': 'Armbar', 'outcome': 'L', 'weight':...
# 3  {'method': 'Pts: 9x4', 'outcome': 'L', 'weight...
# 4  {'method': 'Referee Decision', 'outcome': 'L',...
#
#                                                  8    \
# 0  {'method': 'Triangle armbar', 'outcome': 'L', ...
# 1  {'method': 'Kneebar', 'outcome': 'L', 'weight'...
# 2  {'method': 'Pts: 2x0', 'outcome': 'L', 'weight...
# 3  {'method': 'Choke from back', 'outcome': 'L', ...
# 4  {'method': 'Points', 'outcome': 'L', 'weight':...
#
#                                                  9    ...   283   284   285  \
# 0  {'method': 'Choke from back', 'outcome': 'L', ...  ...  None  None  None
# 1  {'method': 'Pts: 5x0', 'outcome': 'L', 'weight...  ...  None  None  None
# 2  {'method': 'Pts: 3x0', 'outcome': 'L', 'weight...  ...  None  None  None
# 3  {'method': 'Referee Decision', 'outcome': 'L',...  ...  None  None  None
# 4  {'method': 'Kneebar', 'outcome': 'L', 'weight'...  ...  None  None  None
#
#     286   287   288   289   290   291   292
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
#
# [5 rows x 293 columns]

# %% [markdown]
# This is absolutely not what I wanted, so let's combine all of these lists and see what kind of dataframe we get there.

# %%
combined_list = []
for item in new_data:
    combined_list+=item

new_df = pd.DataFrame(combined_list)
new_df.head()
# Out:
#              method outcome weight  year           name
# 0  Inside heel hook       L    ABS  2015  Aaron Johnson
# 1               RNC       L   94KG  2015  Aaron Johnson
# 2         Heel hook       L    ABS  2015  Aaron Johnson
# 3            Points       L   94KG  2016  Aaron Johnson
# 4               N/A       L   94KG  2016  Aaron Johnson

# %% [markdown]
# This is a much better format and should allow me to manipulate this data much more efficiently than before. I'm gonna save this as a csv for now and move on to reshaping this data so i can visualize it.

# %%
new_df.to_csv('bjjheroes_matches.csv')
